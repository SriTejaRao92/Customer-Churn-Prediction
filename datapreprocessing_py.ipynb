# %% [markdown]
# <a href="https://colab.research.google.com/github/SriTejaRao92/Customer-Churn-Prediction/blob/main/datapreprocessing_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install xgboost

# %% [markdown]
# # New Section

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

def load_data(filepath):
    """
    Load the dataset from the given filepath.
    """
    return pd.read_csv(filepath)

def preprocess_data(data):
    """
    Preprocess the data by handling missing values, encoding categorical variables,
    and normalizing numerical features.
    """
    # Drop rows with missing values
    data.dropna(inplace=True)

    # Encode categorical variables
    data['gender'] = data['gender'].map({'Male': 1, 'Female': 0})
    data = pd.get_dummies(data, columns=['Partner', 'Dependents', 'PhoneService', 'MultipleLines',
                                         'InternetService', 'OnlineSecurity', 'OnlineBackup',
                                         'DeviceProtection', 'TechSupport', 'StreamingTV',
                                         'StreamingMovies', 'Contract', 'PaperlessBilling',
                                         'PaymentMethod'], drop_first=True)


    # Replace empty strings with NaN in numerical columns
    data[['tenure', 'MonthlyCharges', 'TotalCharges']] = data[['tenure', 'MonthlyCharges', 'TotalCharges']].replace(' ', pd.NA)

    # Drop rows with NaN in numerical columns
    data.dropna(subset=['tenure', 'MonthlyCharges', 'TotalCharges'], inplace=True)

    # Normalize numerical features
    scaler = StandardScaler()
    data[['tenure', 'MonthlyCharges', 'TotalCharges']] = scaler.fit_transform(data[['tenure', 'MonthlyCharges', 'TotalCharges']])
    return data
# Upload the file to the current environment (if needed)
# In Google Colab, you can use the file upload feature in the Files tab
from google.colab import files
uploaded = files.upload()
# Verify the file exists in the expected location
# !ls

# Load and preprocess data
data_path = 'telco_customer_churn.csv'  # Update this path to the location of your file in Google Drive
data = load_data(data_path)
data = preprocess_data(data)
data.to_csv('preprocessed_data.csv', index=False)
# Out:
#      <input type="file" id="files-2a091a64-e6e3-486e-ae67-38b22bf8f786" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a091a64-e6e3-486e-ae67-38b22bf8f786">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
